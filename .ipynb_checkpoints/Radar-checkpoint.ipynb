# %% [markdown]
# <b><font size=20, color='#A020F0'>AOS573 Final Project</font></b>

# %% [markdown]
# #### Matt Oehler

# %% [markdown]
# ### Project Overview
# The goal of this project is to be able to read in NEXRAD level II archive radar data from the [NWS database](https://s3.amazonaws.com/noaa-nexrad-level2/index.html), filter out lower reflectivities (<30dbz), and track the most intense part of the storms as they move and develop in time. The package doing most of the heavy lifting will be [Py-ART](https://arm-doe.github.io/pyart/), Python ARM (Atmospheric Radiation Measuting) Radar Toolkit. This meant learning a new (and quite in depth I might add) Python package, all its cababilities, and how *friendly* it is with other packages.
#
# For this study, we will be tracking a storm that hit the Twin Cities area the evening of August 26th, 2024. To set the scene, a hot and humid air mass settled across the region beginning Sunday, August 25 and lasting through Monday, August 26. On Monday afternoon, heat indices exceed 100 degrees in many locations. This warm, unstable air was followed by two rounds of severe weather over the next 12 hours. On Monday afternoon, thunderstorms developed across western Minnesota, and formed into a line producing wind damage across central and eastern Minnesota, and western Wisconsin. Later that night into Tuesday morning, another round of storms developed and produced wind damage in eastern Minnesota and western Wisconsin. [News sources](https://www.cbsnews.com/minnesota/pictures/minnesota-state-fair-storm-damage-aug-27-2024/4/) stated that it did the unprecedented and forced the beloved Minnesota State Fair to open late on Tuesday.
#
#
#
# #### Notes
# 1. Goal is to track the most intense parts of storms <>30dbz) to give speed and direction of movement
# 2. Focusing on elevation angle of 0.5 degrees (sweep 0)
# 3. Use distance from radar and angle or lat/lon???

# %%
import pyart
import matplotlib.pyplot as plt
import xarray as xr
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import numpy as np
import scipy.signal
import geopandas as gpd
# import tensorflow 
import xradar as xd
from copy import deepcopy
import geopandas
import math
# Out:
# ## You are using the Python ARM Radar Toolkit (Py-ART), an open source
# ## library for working with weather radar data. Py-ART is partly
# ## supported by the U.S. Department of Energy as part of the Atmospheric
# ## Radiation Measurement (ARM) Climate Research Facility, an Office of
# ## Science user facility.
# ##
# ## If you use this software to prepare a publication, please cite:
# ##
# ##     JJ Helmus and SM Collis, JORS 2016, doi: 10.5334/jors.119

# %%
#Import frames of data
aws_nexrad_level2_file = ("s3://noaa-nexrad-level2/2024/08/26/KMPX/KMPX20240826_215132_V06")
aws_nexrad_level2_file2 = ("s3://noaa-nexrad-level2/2024/08/26/KMPX/KMPX20240826_215759_V06")

#Read the data into a usable format and exclude unnecessary fields
radar = pyart.io.read_nexrad_archive(aws_nexrad_level2_file, exclude_fields=('cross_correlation_ratio',
 'differential_reflectivity',
 'velocity',
 'clutter_filter_power_removed',
 'spectrum_width',
 'differential_phase'))
radar2 = pyart.io.read_nexrad_archive(aws_nexrad_level2_file2, exclude_fields=('cross_correlation_ratio',
 'differential_reflectivity',
 'velocity',
 'clutter_filter_power_removed',
 'spectrum_width',
 'differential_phase'))

#List radar variables in data
list(radar.fields)
# Out:
# ['reflectivity']

# %%
range = radar.range['data']
data = radar.fields['reflectivity']['data'].data[:]
ref = np.concatenate(data).ravel()
range.shape
# Out:
# (1832,)

# %%
angle = radar.azimuth['data']
angle.shape
# Out:
# (11880,)

# %%
range_filt = np.where(radar.fields['reflectivity']['data'] > 30, radar.range['data'], np.nan)
range_filt
# Out:
# array([[nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        ...,
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan]], dtype=float32)

# %%
R, Theta = np.meshgrid(r, theta)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 R, Theta = np.meshgrid(r, theta)
#
# NameError: name 'r' is not defined

# %%
radar.range['data']
# Out:
# array([  2125.,   2375.,   2625., ..., 459375., 459625., 459875.],
#       dtype=float32)

# %%
filt.data[:,0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 filt.data[:,0]
#
# NameError: name 'filt' is not defined

# %%
angle_filt = np.where(filt.data[:,0] > 30, radar.azimuth['data'], np.nan)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 angle_filt = np.where(filt.data[:,0] > 30, radar.azimuth['data'], np.nan)
#
# NameError: name 'filt' is not defined

# %%
count = len([x for x in range_filt if not math.isnan(x)])

print(count)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 count = len([x for x in range_filt if not math.isnan(x)])
#       3 print(count)
#
# TypeError: only length-1 arrays can be converted to Python scalars

# %%
# Generate sample data
r = range
theta = angle
R, Theta = np.meshgrid(r, theta)
Z = data

# Create polar plot
fig, ax = plt.subplots(subplot_kw={'projection': 'polar'},)

# Create contour plot
contour_plot = ax.contourf(Theta, R, Z, cmap='pyart_HomeyerRainbow')

# Add colorbar
plt.colorbar(contour_plot)

# Set title
ax.set_title('Polar Contour Plot')

# Show plot
plt.show()

# %%
r = range
theta = angle
colors = ref

# fig, ax = plt.subplots(subplot_kw={'projection': 'polar'})
fig = plt.figure()
ax = fig.add_subplot(111, projection='polar')
ax.scatter(theta, r, c=colors, cmap='pyart_HomeyerRainbow')

ax.set_rticks([0.5, 1, 1.5, 2])  # Less radial ticks
ax.set_rlabel_position(-22.5)  # Move radial labels away from plotted line
ax.grid(True)

ax.set_title("A line plot on a polar axis", va='bottom')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 8
#       6 fig = plt.figure()
#       7 ax = fig.add_subplot(111, projection='polar')
# ----> 8 ax.scatter(theta, r, c=colors, cmap='pyart_HomeyerRainbow')
#      10 ax.set_rticks([0.5, 1, 1.5, 2])  # Less radial ticks
#      11 ax.set_rlabel_position(-22.5)  # Move radial labels away from plotted line
#
# File /opt/conda/envs/uwb-fall-2024/lib/python3.12/site-packages/matplotlib/__init__.py:1473, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1470 @functools.wraps(func)
#    1471 def inner(ax, *args, data=None, **kwargs):
#    1472     if data is None:
# -> 1473         return func(
#    1474             ax,
#    1475             *map(sanitize_sequence, args),
#    1476             **{k: sanitize_sequence(v) for k, v in kwargs.items()})
#    1478     bound = new_sig.bind(ax, *args, **kwargs)
#    1479     auto_label = (bound.arguments.get(label_namer)
#    1480                   or bound.kwargs.get(label_namer))
#
# File /opt/conda/envs/uwb-fall-2024/lib/python3.12/site-packages/matplotlib/axes/_axes.py:4787, in Axes.scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, **kwargs)
#    4785 y = np.ma.ravel(y)
#    4786 if x.size != y.size:
# -> 4787     raise ValueError("x and y must be the same size")
#    4789 if s is None:
#    4790     s = (20 if mpl.rcParams['_internal.classic_mode'] else
#    4791          mpl.rcParams['lines.markersize'] ** 2.0)
#
# ValueError: x and y must be the same size

# %%
# Create gatefilter and copy reflectivity field
gatefilter = pyart.correct.GateFilter(radar)
gatefilter.exclude_below('reflectivity', 30)
nf = deepcopy(radar.fields['reflectivity'])
# 
# Apply gatefilter to coppied field and add field to data
nf['data'] = np.ma.masked_where(gatefilter.gate_excluded, nf['data'])
radar.add_field('filtered_reflectivity', nf, replace_existing=True)

#List radar variables in data
list(radar.fields)
# Out:
# ['reflectivity', 'filtered_reflectivity']

# %%
# Extract the latitude and longitude of the radar and use it for the center of the map
lat_center = round(radar.latitude['data'][0], 0)
lon_center = round(radar.longitude['data'][0], 0)


# Determine the ticks
lat_ticks = np.arange(lat_center-3, lat_center+3, 1.5)
lon_ticks = np.arange(lon_center-3, lon_center+3, 1.5)

# %%
# Plot radar reflectivity in polar coordinates (not sure if helpful yet, probs not)
display = pyart.graph.RadarDisplay(radar)
fig = plt.figure(figsize=(6, 5))
ax = plt.subplot(121, projection=ccrs.PlateCarree())

# plot super resolution reflectivity
ax = fig.add_subplot(111)
display.plot(
    "reflectivity",
    0,
    title="NEXRAD Reflectivity",
    vmin=-32,
    vmax=64,
    colorbar_label="Equivalent Relectivity ($Z_{e}$) \n (dBZ)",
    ax=ax,
)
# ax.add_feature(cfeature.STATES, linewidth=0.5, edgecolor='black')
display.plot_range_ring(radar.range["data"][-1] / 1000.0, ax=ax)
display.set_limits(xlim=(-500, 500), ylim=(-500, 500), ax=ax)
plt.show()

# %%
display = pyart.graph.RadarDisplay(radar )
fig = plt.figure(figsize=(6, 5))
ax = plt.subplot(121, projection=ccrs.PlateCarree())

# plot super resolution reflectivity
ax = fig.add_subplot(111)
display.plot(
    "filtered_reflectivity",
    0,
    title="NEXRAD Reflectivity",
    vmin=-32,
    vmax=64,
    colorbar_label="Equivalent Relectivity ($Z_{e}$) \n (dBZ)",
    ax=ax,

)
display.plot_range_ring(radar.range["data"][-1] / 1000.0, ax=ax)
display.set_limits(xlim=(-500, 500), ylim=(-500, 500), ax=ax)
plt.show()

# %%
# az = pyart.core.Radar.get_azimuth(radar, sweep=0, copy=True)
# range = pyart.core.Radar.get_range(radar, sweep=0,copy=True)

# %%
# Get lat/lon points using function
latlon = radar.get_gate_lat_lon_alt(0, reset_gate_coords=False, filter_transitions=True)
# Separate lat/lon into individual variables
lat = list(latlon[0])
lon = list(latlon[1])

# %%
lat_flat = np.concatenate(lat).ravel()
lat_flat.shape
# Out:
# (1319040,)

# %%
lon_flat = np.concatenate(lon).ravel()
lon_flat.shape
# Out:
# (1319040,)

# %%
data = radar.fields['reflectivity']['data'].data[:]
ref = np.concatenate(data).ravel()
ref.shape
# Out:
# (21764160,)

# %%
lat_filt = np.where(radar.fields['reflectivity']['data'].data > 30, lat, np.nan)
# lon_filt = np.where(radar.fields['reflectivity']['data'][1] > 30, lon, np.nan)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[113], line 1
# ----> 1 lat_filt = np.where(radar.fields['reflectivity']['data'].data > 30, lat, np.nan)
#       2 # lon_filt = np.where(radar.fields['reflectivity']['data'][1] > 30, lon, np.nan)
#
# ValueError: operands could not be broadcast together with shapes (11880,1832) (720,1832) ()

# %%
# list(lat_filt)

# %%
#plot reflectivity for frame 1
fig = plt.figure(figsize=(12, 4))
display = pyart.graph.RadarMapDisplay(radar)

ax = plt.subplot(121, projection=ccrs.PlateCarree())

display.plot_ppi_map(
    "reflectivity",
    sweep=0,
    ax=ax,
    colorbar_label="Equivalent Relectivity ($Z_{e}$) \n (dBZ)",
    vmin=-20,
    vmax=60,
)

#plot reflectivity for frame 2
fig = plt.figure(figsize=(12, 4))
display = pyart.graph.RadarMapDisplay(radar2)

ax = plt.subplot(121, projection=ccrs.PlateCarree())

display.plot_ppi_map(
    "reflectivity",
    sweep=0,
    ax=ax,
    colorbar_label="Equivalent Relectivity ($Z_{e}$) \n (dBZ)",
    vmin=-20,
    vmax=60,
)

# %%
#plot filtered relectivity values (30 dbz or greater)
fig = plt.figure(figsize=(12, 4))
display = pyart.graph.RadarMapDisplay(radar)

ax = plt.subplot(121, projection=ccrs.PlateCarree())

display.plot_ppi_map(
    'filtered_reflectivity',
    sweep=0,
    ax=ax,
    colorbar_label="Equivalent Relectivity ($Z_{e}$) \n (dBZ)",
    vmin=-20,
    vmax=60,
)

# fig = plt.figure(figsize=(12, 4))
# display = pyart.graph.RadarMapDisplay(radar2)

# ax = plt.subplot(121, projection=ccrs.PlateCarree())

# display.plot_ppi_map(
#     'filtered_reflectivity',
#     sweep=0,
#     ax=ax,
#     colorbar_label="Equivalent Relectivity ($Z_{e}$) \n (dBZ)",
#     vmin=-20,
#     vmax=60,
# )

# %%
# gate_latitude = LazyLoadDict(get_metadata("gate_latitude"))
# gate_latitude.set_lazy("data", _gate_lon_lat_data_factory(self, 1))
# self.gate_latitude = gate_latitude

# %%
radar.fields['filtered_reflectivity']
# Out:
# {'units': 'dBZ',
#  'standard_name': 'equivalent_reflectivity_factor',
#  'long_name': 'Reflectivity',
#  'valid_max': 94.5,
#  'valid_min': -32.0,
#  'coordinates': 'elevation azimuth range',
#  '_FillValue': -9999.0,
#  'data': masked_array(
#    data=[[--, --, --, ..., --, --, --],
#          [--, --, --, ..., --, --, --],
#          [--, --, --, ..., --, --, --],
#          ...,
#          [--, --, --, ..., --, --, --],
#          [--, --, --, ..., --, --, --],
#          [--, --, --, ..., --, --, --]],
#    mask=[[ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True],
#          ...,
#          [ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True]],
#    fill_value=1e+20,
#    dtype=float32)}

# %%
# pyart.core.Radar.get_gate_lat_lon_alt(radar, edges=False)

# %%
# test = radar.fields['filtered_reflectivity']
pyart.core.Radar.get_field(radar, 0, field_name='filtered_reflectivity')
# Out:
# masked_array(
#   data=[[--, --, --, ..., --, --, --],
#         [--, --, --, ..., --, --, --],
#         [--, --, --, ..., --, --, --],
#         ...,
#         [--, --, --, ..., --, --, --],
#         [--, --, --, ..., --, --, --],
#         [--, --, --, ..., --, --, --]],
#   mask=[[ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         ...,
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True]],
#   fill_value=1e+20,
#   dtype=float32)

# %%
# pyart.filters.moment_and_texture_based_gate_filter(radar,

# %%
# gate_mapper = pyart.map.GateMapper(radar, radar2, gatefilter_src=gatefilter)
# # Get the destination radar's equivalent of (2, 2) in the source radar's coordinates
# dest_index = gate_mapper[2, 2]
# radar_mapped = gate_mapper.mapped_radar(['reflectivity'])
